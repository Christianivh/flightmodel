# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import cm

import itertools

flightdata = pd.read_csv('datos.csv',sep=';')
flightdata.head(5)
# Out:
#       ID  aniomes  year   month carrier  filtro          carrier_name airport  \
# 0  ASABQ   201501  2015       1      AS       1  Alaska Airlines Inc.     ABQ
# 1  ASABQ   201502  2015       2      AS       1  Alaska Airlines Inc.     ABQ
# 2  ASABQ   201503  2015       3      AS       1  Alaska Airlines Inc.     ABQ
# 3  ASABQ   201504  2015       4      AS       1  Alaska Airlines Inc.     ABQ
# 4  ASABQ   201505  2015       5      AS       1  Alaska Airlines Inc.     ABQ
#
#                                         airport_name  arr_flights  \
# 0  Albuquerque, NM: Albuquerque International Sun...           31
# 1  Albuquerque, NM: Albuquerque International Sun...           28
# 2  Albuquerque, NM: Albuquerque International Sun...           31
# 3  Albuquerque, NM: Albuquerque International Sun...           30
# 4  Albuquerque, NM: Albuquerque International Sun...           31
#
#              ...             late_aircraft_ct  arr_cancelled  arr_diverted  \
# ...

# %%
flightdata.shape
# Out:
# (32751, 24)

# %%
flightdata = flightdata.fillna(flightdata.median())
flightdata.isnull().sum()
# Out:
# ID                          0
# aniomes                     0
# year                        0
#  month                      0
# carrier                     0
# filtro                      0
# carrier_name                0
# airport                     0
# airport_name                0
# arr_flights                 0
# carrier_ct                  0
#  weather_ct                 0
# nas_ct                      0
# security_ct                 0
# late_aircraft_ct            0
# arr_cancelled               0
# arr_diverted                0
#  arr_delay                  0
#  carrier_delay              0
# weather_delay               0
# nas_delay                   0
# security_delay              0
# late_aircraft_delay         0
# target_vuelos_de_retraso    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pickle



unit = set(flightdata['ID'])
maxtam = len(unit)
maxtam

s = []

for i in range(1,maxtam):
    print("Ejecutando ",list(unit)[i])
    mvalor = list(unit)[i]
    Mod = flightdata[(flightdata['ID'] == mvalor)]
    entrenamiento = Mod[(Mod['filtro'] == 1)]
    testing = Mod[(Mod['filtro'] == 0)]
    testing.sort_values(by=['aniomes'])
    
    ## creacion de entrenamiento
    
    X_train = entrenamiento[(['arr_flights', 'carrier_ct', ' weather_ct','nas_ct'])]
    y_train = entrenamiento[(['target_vuelos_de_retraso'])]
    
    ## creacion de testing
    X_test= testing[(['arr_flights', 'carrier_ct', ' weather_ct','nas_ct'])]
    y_test = testing[(['target_vuelos_de_retraso'])]
    
    #### modelo 
    regr = LinearRegression()
    regr.fit(X_train.values, y_train.values)
    y_pred = regr.predict(X_test.values)
    pickle.dump( regr, open('d:/Users/gnunuvero/Desktop/modelos_vuelos/' + mvalor + '.pkl', 'wb'))
    #ECM = mean_squared_error(y_test.values, y_pred)
    s.append(y_pred)
    # The coefficients
# Out:
# Ejecutando  AARIC
# Ejecutando  OOTUL
# Ejecutando  VXJFK
# Ejecutando  UASAT
# Ejecutando  F9DTW
# Ejecutando  EVMTJ
# Ejecutando  B6CLT
# Ejecutando  WNDCA
# Ejecutando  UAGRR
# Ejecutando  OOAVP
# Ejecutando  HALAX
# Ejecutando  VXSEA
# Ejecutando  HALAS
# Ejecutando  OOALB
# Ejecutando  UAMSN
# Ejecutando  AAIND
# Ejecutando  EVFWA
# Ejecutando  EVLRD
# Ejecutando  OOCHO
# Ejecutando  EVGSP
# Ejecutando  B6BNA
# Ejecutando  F9PHL
# Ejecutando  ASOMA
# Ejecutando  EVTLH
# Ejecutando  OOFNT
# Ejecutando  OOEVV
# Ejecutando  DLLAS
# Ejecutando  EVLEX
# Ejecutando  DLJAN
# Ejecutando  DLBIS
# Ejecutando  EVFAY
# Ejecutando  DLIAH
# Ejecutando  DLLFT
# Ejecutando  EVAVL
# Ejecutando  EVMCO
# Ejecutando  EVMSY
# Ejecutando  HAKOA
# Ejecutando  B6DFW
# Ejecutando  OOMKG
# Ejecutando  DLEGE
# Ejecutando  OOSPI
# Ejecutando  OOTWF
# Ejecutando  UAGUM
# Ejecutando  VXLAX
# Ejecutando  AASYR
# Ejecutando  EVFSM
# Ejecutando  WNELP
# Ejecutando  UAANC
# Ejecutando  OOPVD
# Ejecutando  B6ORH
# ...
